# %% [markdown]
# ### Урок 5. Проверка статистических гипотез. P-значения. Доверительные интервалы. A/B-тестирование

# %% [markdown]
# ##### 1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# $$T_{1,2} = \overline{X} \pm \frac{\sigma}{\sqrt{n}} \cdot Z_{\frac{α}{2}}$$

# %%
import numpy as np

sigma = 16
mean = 80
p = 0.95
n = 256
Z = 1.96

T = (mean - Z * sigma / np.sqrt(n), mean + Z * sigma / np.sqrt(n))
print('T =', T)
# Out:
# T = (78.04, 81.96)

# %% [markdown]
# ##### 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1 Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95

# %%
data = [6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1]

avg = sum(data) / len(data)
print('Среднее арифметическое:', avg, '\n')

var_unbiased = sum([(x-avg)**2 for x in data]) / (len(data) - 1)
print('Несмещенная дисперсия:', var_unbiased, '\n')

std = np.sqrt(var_unbiased)
print('Среднее квадратичное отклонение:', std, '\n')

t = 2.262

T = (avg - t * std / np.sqrt(len(data)), avg + t * std / np.sqrt(len(data)))
print('Доверительный итервал: ', T, '\n')
print(T[0], '< a <', T[1], '– данный интервал с вероятностью 0.95 накрывает истинное значение измеряемой величины X')
# Out:
# Среднее арифметическое: 6.589999999999999
#
# Несмещенная дисперсия: 0.2032222222222223
#
# Среднее квадратичное отклонение: 0.4508017549014448
#
# Доверительный итервал:  (6.267538255912425, 6.912461744087573)
#
# 6.267538255912425 < a < 6.912461744087573 – данный интервал с вероятностью 0.95 накрывает истинное значение измеряемой величины X

# %% [markdown]
# ##### 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв.мм

# %%
n = 100
std = 2
H0 = 17
H1 = 17.5

Zp = 1.645

Zh = (H1 - H0) / (std / np.sqrt(n))
print('Zh = ', Zh)
# Out:
# Zh =  2.5

# %% [markdown]
# Zh > Zp следовательно нулевая гипотеза о среднем диаметре шарика 17мм не верна

# %% [markdown]
# ##### 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
data = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]

avg = sum(data) / len(data)
print('Среднее арифметическое:', avg, '\n')

var_unbiased = sum([(x-avg)**2 for x in data]) / (len(data) - 1)
print('Несмещенная дисперсия:', var_unbiased, '\n')

std = np.sqrt(var_unbiased)
print('Среднее квадратичное отклонение:', std, '\n')

H0 = 200

Th = (avg - H0) / (std / np.sqrt(len(data)))
print('Наблюдаемое значение критерия: ', Th)

Tp = 2.281
# Out:
# Среднее арифметическое: 198.5
#
# Несмещенная дисперсия: 19.833333333333332
#
# Среднее квадратичное отклонение: 4.453463071962462
#
# Наблюдаемое значение критерия:  -1.0651074037450896

# %% [markdown]
# |Th| < Tp, следовательно утверждение продавца верно
