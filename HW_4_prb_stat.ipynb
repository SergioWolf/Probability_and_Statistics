# %% [markdown]
# ### Урок 4. Непрерывные случайные величины. Функция распределения и плотность распределения вероятностей. Равномерное и нормальное распределение. Центральная предельная теорема

# %% [markdown]
# ##### 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800]. Найдите ее среднее значение и дисперсию.

# %%
import numpy as np

a = 200
b = 800

Ma = (b + a) / 2
Da = (b - a)**2 / 12

print('Среднее значение: ', Ma)
print('Дисперсия: ', Da)
# Out:
# Среднее значение:  500.0
# Дисперсия:  30000.0

# %% [markdown]
# ##### 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %%
Db = 0.2
a = 0.5

b = np.sqrt(Db*12) + a
Mb = (b + a) / 2

print('Правая граница: ', b)
print('Среднее значение: ', Mb)
# Out:
# Правая граница:  2.049193338482967
# Среднее значение:  1.2745966692414834

# %% [markdown]
# ##### 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32). Найдите: а). M(X) б). D(X) в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# Согласно  $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$ следует:

# %% [markdown]
# M(X) = 2, D(X) = 16, std(X) = 4

# %% [markdown]
# ##### 4. Рост взрослого населения города X имеет нормальное распределение. Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см. Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост: а). больше 182 см, б). больше 190 см, в). от 166 см до 190 см, г). от 166 см до 182 см, д). от 158 см до 190 см, е). не выше 150 см или не ниже 190 см, ё). не выше 150 см или не ниже 198 см, ж). ниже 166 см.

# %% [markdown]
# $a)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $182$ см для города $X$: $$\sigma = \frac{182-174}{8} = 1$$
# Так как интервал от $a - \sigma$ до $a + \sigma$ содержит около $68\%$ вероятностной массы, то оставшаяся вероятностная масса равна $100\% - 68\% = 32\%$. Исходя из того, что функция нормального распределения зеркальная, а нам нужна только правая часть вероятностной массы, то получим, что вероятность встретить взрослого человека ростом больше $182$ см равна $\frac{32}{2}\%=16\%$
#
# $P(Z>1) = 1- P(Z<1) = 1 - 0,84 = 0,16$

# %% [markdown]
# $б)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $190$ см для города $X$: $$\sigma = \frac{190-174}{8} = 2$$
# Так как интервал от $a - 2\sigma$ до $a + 2\sigma$ содержит около $95,4\%$ вероятностной массы, то оставшаяся вероятностная масса равна $100\% - 95,4\% = 4,6\%$. Исходя из того, что функция нормального распределения зеркальная, а нам нужна только правая часть вероятностной массы, то получим, что вероятность встретить взрослого человека ростом больше $190$ см равна $\frac{4,6}{2}\%=2,3\%$
#
# $P(Z>2) = 1- P(Z<2) = 1 - 0,9772 = 0,0228$

# %% [markdown]
# $в)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $166$ см для города $X$: $$\sigma = \frac{166-174}{8} = -1$$
# Также найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $190$ см для города $X$: $$\sigma = \frac{190-174}{8} = 2$$
# Интервал от $a - \sigma$ до $a + \sigma$ содержит около $68\%$ вероятностной массы. Исходя из того, что функция нормального распределения зеркальная, вероятностная масса от $a - \sigma$ до $a$ равна $\frac{68}{2}\% = 34\%$.
# Интервал от $a - 2\sigma$ до $a + 2\sigma$ содержит около $95,4\%$ вероятностной массы. Исходя из того, что функция нормального распределения зеркальная, вероятностная масса от $a$ до $a + 2\sigma$ равна $\frac{95,4}{2}\% = 47,7\%$.
# Общая вероятностная масса от $166$ см до $190$ см равна $[a - \sigma; a + 2\sigma] = 34\% + 47,7\% = 81,7\%$
#
# $P(-1<Z<2) = 0,9772 - 0,1587 = 0,8185$

# %% [markdown]
# $г)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $166$ см для города $X$: $$\sigma = \frac{166-174}{8} = -1$$
# Также найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $182$ см для города $X$: $$\sigma = \frac{182-174}{8} = 1$$
# Известно, что интервал от $a - \sigma$ до $a + \sigma$ содержит около $68\%$ вероятностной массы. Это и будет вероятностью встретить человека в городе $X$ ростом от $166$ см до $182$.
#
# $P(-1<Z<1) = 0,8413 - 0,1587 = 0,6826$

# %% [markdown]
# $д)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $158$ см для города $X$: $$\sigma = \frac{158-174}{8} = -2$$
# Также найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $190$ см для города $X$: $$\sigma = \frac{190-174}{8} = 2$$
# Известно, что интервал от $a - 2\sigma$ до $a + 2\sigma$ содержит около $95,4\%$ вероятностной массы. Это и будет вероятностью встретить человека в городе $X$ ростом от $158$ см до $190$
#
# $P(-2<Z<2) = 0,9772 - 0,0228 = 0,9544$

# %% [markdown]
# $e)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $150$ см для города $X$: $$\sigma = \frac{150-174}{8} = -3$$
# Также найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $190$ см для города $X$: $$\sigma = \frac{190-174}{8} = 2$$
# Так как интервал от $a - 3\sigma$ до $a + 3\sigma$ содержит около $99,72\%$ вероятностной массы, то оставшаяся вероятностная масса равна $100\% - 99,72\% = 0,28\%$. Исходя из того, что функция нормального распределения зеркальная, а нам нужна только левая часть вероятностной массы, то получим, что вероятность встретить взрослого человека ростом не выше $150$ см равна $\frac{0,28}{2}\% = 0,14\%$.
# Аналогично интервал от $a - 2\sigma$ до $a + 2\sigma$ содержит около $95,4\%$ вероятностной массы, следовательно оставшаяся вероятностная масса равна $100\% - 95,4\% = 4,6\%$. Исходя из того, что функция нормального распределения зеркальная, а нам нужна только правая часть вероятностной массы, то получим, что вероятность встретить взрослого человека ростом не ниже $190$ см равна $\frac{4,6}{2}\% = 2,3\%$.
# Общая вероятностная масса встретить человека не выше $150$ см или не ниже $190$ см равна $[-\infty; a - 3\sigma] + [a + 2\sigma; +\infty] = 0,14\% + 2,3\% = 2,44\%$
#
# $P(-3>Z,Z>2) = 0,0014 + 0,0228 = 0,0242$

# %% [markdown]
# $ё)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $150$ см для города $X$: $$\sigma = \frac{150-174}{8} = -3$$
# Также найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $198$ см для города $X$: $$\sigma = \frac{198-174}{8} = 3$$
# Так как интервал от $a - 3\sigma$ до $a + 3\sigma$ содержит около $99,72\%$ вероятностной массы, то оставшаяся вероятностная масса равна $100\% - 99,72\% = 0,28\%$. Этому значению и равна вероятность встретить человека не выше $150$ см или не ниже $198$ см
#
# $P(-3>Z,Z>3) = 0,0014 + 0,0014 = 0,0028$

# %% [markdown]
# $ж)$ Найдём на сколько средних квадратических отклонений отклоняется рост человека, равный $166$ см для города $X$: $$\sigma = \frac{166-174}{8} = -1$$
# Так как интервал от $a - \sigma$ до $a + \sigma$ содержит около $68\%$ вероятностной массы, то оставшаяся вероятностная масса равна $100\% - 68\% = 32\%$. Исходя из того, что функция нормального распределения зеркальная, а нам нужна только левая часть вероятностной массы, то получим, что вероятность встретить взрослого человека ростом ниже $166$ см равна $\frac{32}{2}\%=16\%$
#
# $P(-1>Z) = 0,1587$

# %% [markdown]
# ##### 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
print('На', (190-178) / np.sqrt(25), 'сигм')
# Out:
# На 2.4 сигм
